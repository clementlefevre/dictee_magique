# %%
import pandas as pd

# %%
df = pd.read_csv("../input/5.txt", header=None)

df.columns=["question"]

df['key']=df.index.astype(int)

df['key']= "q_"+df['key'].map(str)

# %%
df
# Out:
#   question  key
# 0     bebe  q_0
# 1     caca  q_1
# 2     dodo  q_2
# 3     pipi  q_3

# %%
dico = df.to_dict('records')
dico
# Out:
# [{'question': 'bebe', 'key': 'q_0'},
#  {'question': 'caca', 'key': 'q_1'},
#  {'question': 'dodo', 'key': 'q_2'},
#  {'question': 'pipi', 'key': 'q_3'}]

# %%
dico={d['key']:d['question'] for d in dico}
dico

# %%
# Out:
# {'q_0': 'bebe', 'q_1': 'caca', 'q_2': 'dodo', 'q_3': 'pipi'}
