# %%
import pandas as pd

# %%
df = pd.read_csv("questions_draft.txt" )

# %%
df
# Out:
#      question
# 0    Niveau A
# 1      Animal
# 2         Bol
# 3       Bille
# 4    Camarade
# ..        ...
# 141    Skieur
# 142  Souffrir
# 143    Soufre
# 144    Thorax
# 145  Tricycle
#
# [146 rows x 1 columns]

# %%
df['key']=df.index

# %%
df
# Out:
#      question  key
# 0    Niveau A    0
# 1      Animal    1
# 2         Bol    2
# 3       Bille    3
# 4    Camarade    4
# ..        ...  ...
# 141    Skieur  141
# 142  Souffrir  142
# 143    Soufre  143
# 144    Thorax  144
# 145  Tricycle  145
#
# [146 rows x 2 columns]

# %%
df['key']="q_"+df.key.astype(str)
dico = df.to_dict('records')

# %%
lista=[d['key']+" : " +d['question'] for d in dico]

# %%
for i in lista:
    print(i)
# Out:
# q_0 : Niveau A
# q_1 : Animal
# q_2 : Bol
# q_3 : Bille
# q_4 : Camarade
# q_5 : Canal
# q_6 : Caramel
# q_7 : Carnaval
# q_8 : Carton
# q_9 : Chaleur
# q_10 : Chose
# q_11 : Farine
# q_12 : Feu
# q_13 : Fille
# q_14 : Fleur
# q_15 : Fromage
# q_16 : Marche
# q_17 : Neveu
# q_18 : Noir
# q_19 : Parent
# q_20 : Partir
# q_21 : Potiron
# q_22 : Poulet
# q_23 : Premier
# q_24 : Sardine
# q_25 : Seul
# q_26 : Sucre
# q_27 : Tartine
# q_28 : Tasse
# q_29 : Tigre
# q_30 : Trou
# q_31 : Vendredi
# q_32 : Ventre
# q_33 : Vitrine
# q_34 : jambon
# q_35 : Niveau B
# q_36 : Acier
# q_37 : Besoin
# q_38 : Blouse
# q_39 : Bois
# q_40 : Campeur
# q_41 : Chaise
# q_42 : Chance
# q_43 : Chanson
# q_44 : Chienne
# q_45 : Cousin
# q_46 : Deux
# q_47 : Dindon
# q_48 : Espoir
# q_49 : Fleuve
# q_50 : Froid
# q_51 : Gant
# q_52 : Lange
# q_53 : Ligne
# q_54 : Long
# q_55 : Montagne
# q_56 : Orange
# q_57 : Pantalon
# q_58 : Poison
# q_59 : Poisson
# q_60 : Quille
# q_61 : Raisin
# q_62 : Renard
# ...
